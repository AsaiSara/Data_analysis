# %% [markdown]
# # File set up
#  - use only robot utterances and emotions
#  - don't use NONE label -> neutral=0, anger=1, sad=2, happy=3, contentment=4
#       - dialogue model: NONE=0(padding_idx), neutral=1, anger=2, sad=3, happy=4, contentment=5

# %%
import os
import glob
import re
import tqdm
from collections import Counter
import numpy as np

# %% [markdown]
# ## Modify to not using NONE label for recognition
#  - change 0~5 labels -> 0~4 labels (except NONE)
#  - explicit robot utterances and emotions

# %%
def load_files(from_file, out_file):
    file1_dial = open(from_file + '_dial.txt', 'r')
    file2_dial = open(out_file + '_dial.txt', 'w')
    file1_emotion = open(from_file + '_emotion.txt', 'r')
    file2_emotion = open(out_file + '_emotion.txt', 'w')
    
    dials = file1_dial.readlines()
    emotions = file1_emotion.readlines()
    #robo_dials = [dial.split('\t')[1] for dial in dials if len(dial.split('\t')) == 2]
    robo_emotions = [emotion.split('\t')[1].strip() for emotion in emotions if len(emotion.split('\t')) == 2]
    out_dials = []
    out_emotions = []
    
    [(out_dials.append(uttr), out_emotions.append(str(int(emotion)-1))) for (uttr, emotion) in zip(dials, robo_emotions) if emotion != "0"]
    file2_dial.writelines(out_dials)
    file2_emotion.writelines('\n'.join(out_emotions))

# %%
from_dir = "../data/em_dial/splitted"
out_dir = "../emotion_dialogue_model/em_recog/data/em_robo/splitted"
domain = ["/cleaning","/exercise","/lunch","/sleep","/game","/all"]
last_part = ["/test","/valid","/train"]

for d in domain:
    if not os.path.exists(out_dir+d):
        os.makedirs(out_dir+d)
    for l in last_part:
        load_files(from_dir+d+l, out_dir+d+l)
# Out:
# ['まだ綺麗な方だからいいよ。\t部屋を綺麗にできない人はモテないよ\n', 'えー、めんどくさいよ。\tじゃあ、いつするの？\n', 'そうだっけ？\t綺麗な部屋は気持ちがいんだよ。\n', 'どう気持ちがいいの？\t気分がスッキリして晴れやかな気持ちになれるんだよ。\n', '最近ついてなくて気分がすぐれないんだよね。\tそんな時こそ掃除するべきだよ。\n']
# ['まだそんなに散らかっていないよ。\t足の踏み場もないくらいだけど。\n', '必要な物が取りやすくていいんだよ。\tどこに何を置いてあるか分からなくなるでしょう。\n', 'もうある程度の場所は覚えたよ。\tこれだけ物が散乱していると掃除機をかけることも出来ないじゃない。\n', 'だから当分の間は必要ないかな。\t衛生上にもよくないよ。\n', 'そんなに影響がでていると思わないけどなぁ。\tさっきから咳をしているけどそれは埃のせいじゃないかな。\n']
# ['あとでね。今忙しいんだ。\tあとであとでって言うばかりでいつも片付けないじゃないか。\n', 'だってめんどくさいんだもん。そんなに部屋を綺麗にしたいならロボットが掃除したらいいじゃないか。\t私が掃除してもAさんのためにならないよ。掃除してあげてもいいけど私がいなくなったあと誰が掃除するの?\n', '…。ロボットはいなくならないでしょ?\tそれはわからないよ。いつ離れ離れになるか…。そのためにわたしが今指導しているのだよ。\n', 'うーん。でも今は漫画を読んでいるから。無理。\tどうしてこれだけ言ってもわかってくれないの！掃除しないのなら全部捨てるよ！\n', 'え、だめだめ。捨てたらだめだよ、大切なものばかりなんだから。\tだったらなおさら自分で片付けなさい！私だって怒るときは怒るんだ！\n']
# ['外は暑いからめんどくさいよ。\tですが、天気が良いですよ。\n', 'え、どこに行くの\tそうですね、噴水がある涼しい公園などいかがですか\n', 'うーんそこなら良いかも\t公園までウォーキングし涼しいところを見つけ冷たい麦茶でも飲んではいかがですか\n', 'そうだね運動したら汗をかくから水分をとらないとね\tそうです運動したらしっかり水分を補給して下さい\n', 'でもやっぱり外は暑いな〜\t帽子をかぶり、キンキンに冷えた麦茶のペットボトルを体にあて冷やしながら行くのはいかがですか\n']
# ['分かってる。\tジョギング行けよ。\n', '分かっているよ。\t分かっているのは口だけかよ。\n', 'そんなことないよ。\t何で走りに行かないんだよ。\n', 'めんどくさいし。\tふざけるなよ、約束守れよい。\n', 'もっと優しく言えないのかよ。\tなんで、約束守れないやつに優しく言わなきゃならないんだよ。\n']
# ['仕事が忙しいし、疲れて帰宅してから運動するのは事実上難しいよ。\tまだ若いからいいけれど、年齢を重ねるにつれ、日頃の運動不足が身体に与える影響は次第に大きくなるよ。\n', 'もともと運動するのはあまり好きじゃないし、身体をハードに動かすのは慣れてないから、仕方ないと思って諦めてる。\t諦めるなんて言われると寂しくなるよ。\n', '申し訳ないけど、運動しようというモチベーションが低いから、よっぽどメリットがない始めようとは思わない。\t運動するメリットはいろいろあるよ。\n', '例えばどんなメリットがあるの？\tまずは消費カロリーが増えるから、ダイエットに効果があり、体重が減ったり、身体が引き締まったりする。\n', 'そういえば最近コンビニドーナツの食べ過ぎで、お腹が出てきているような気がする。\t血流が良くなって汗もたくさんかくし、デトックス効果も得られて、見た目が若返るよ。\n']
# ['でも、今日のおかずは僕の嫌いなほうれん草が入っているんだ。\tでも、おかずを残してしまうとほうれん草を作ってくれた農家の方やおかずを作ってくれたお母さんが悲しむよ。\n', 'そうだね。じゃあ、誰かに代わりに食べてもらうよ。\tお母さんは君が毎日必要な栄養を計算してご飯を作っているんだよ。全部食べなきゃバランスの取れた生活がおくれないよ。\n', 'ちょっとくらいとらなくても大丈夫だよ。\tチリも積もれば山となるって言うし、ほうれん草にしかない栄養分もあるんだよ。\n', 'そうなんだ。でも、最近はサプリメントでも栄養は補給できるよ。\tサプリメントでは、吸収率が下がってしまうから、なるべく食物から食べるべきだよ。\n', 'さっきから栄養とか言ってるけど、僕は健康だよ？\t今は健康でも、大人になってから体調が悪くなるかもしれないよ。わたしは君が大人になって病気になって会えなくなると悲しい。\n']
# ['俺が茄子が苦手だって知ってるだろー\t彼女さんは全部食べてくれたよ？\n', 'なら俺の分も食べてもらおっかなー？\tいんや、お残しは許しまへん！\n', 'じゃあ後で食べるから置いといて。\tふぇぇん、こんなこと言う子じゃなかったのにー\n', 'あ、このやり取り昔からだから。\t転んだ私に絆創膏貼ってくれた子が…クスン\n', '優しい子だったのよ？俺って。\tオネショシーツを洗おうと頑張ってた子が…クスン\n']
# ['もうお腹がいっぱいだからね。\tママが買ってきたケーキもう食べられないってこと？\n', '甘いものは別腹かな?。\t言っておくけど、出されたものを食べきらないとおやつもなしだよ！\n', 'そんな?。\t当たり前でしょ！\n', 'しかし、今日は僕の誕生日。。\t関係ないでしょ！\n', 'ケーキを残すより、ご飯を残した方がよいと思うな。\tケーキは、私が食べるから心配いらないよ。\n']
# ['あと、ちょっと！\t早く寝ないと明日の朝起きれないですよ。\n', '大丈夫だよ。\t大丈夫じゃないですよ。この前も寝過ごしたじゃないですか。\n', '任しといて！\tいい加減にしてください！\n', 'なんだよ！\tAさんは、失敗したあとにいつも後悔しています。\n', 'え？\t今まで後悔して悲しい顔をするAさんを何回も見てきました。\n']
# ['そうだっけ？\tはい、もう寝た方が良いですよ。\n', 'なんで？\tこの時間に寝た方が生活のリズムが整います。\n', 'まだ、やりたいことがあるんだよなぁ。\t生活にはリズムが必要です！\n', 'そうかなぁ、そんなにキッチリしなくてもさ。\tキッチリした方がAさんの体にも脳にも良い影響があるんです！\n', 'へぇ〜。\t僕はAさんが幸せな生活を送ることを応援しているんです！\n']
# ['この動画が終わったらね。\tAさん、そんなのいつでも見れるじゃないデスカ。\n', '明日からの目標にするよ。\tそれ、前にも言ってマシタヨ…。\n', 'あとちょっとだけ待って?。\tワタシはAさんが規則正しい生活を送れるようになるためにAさんの側に居るのに…ワタシは役に立てないんデショウカ…。\n', 'そんな悲しそうにしないでよ?。\tだって…Aさんの夜更かし癖、ちっとも直らないじゃないデスカ…。Aさんのサポートロボット、ワタシは失格デス…。ウゥ…。\n', '泣かないでよ。分かったよ、もう寝るしこれからはもっと早く寝るようにするよ。\t本当デスカ??\n']
# ['今いいところなんだからちょっと待ってよ。\tそんなに長時間ゲームをしていると目にも良くないよ。\n', '今まで視力が悪くなったことがないから大丈夫。\t目が疲れると体にも悪いんだよ。\n', 'ゲームを止めたら体を休めるから平気だよ。\tちゃんと時間を決めていたのに意味ないじゃないか。\n', 'でも今止めたらまたやり直しになっちゃうよ。\tだからちゃんと計画してやらないと駄目なんだよ。\n', 'これからはちゃんとするから。\tそう思うなら今すぐに実行しないと。\n']
# ['えー、今、まだちょっとセーブできないんだ。\tダメですよ。すぐやめてください。お母さんに叱られますよ。\n', 'ゲーム、セーブできないんだってばぁ。しょうがないじゃん。\tおかあさんに怒られますよ。\n', 'でも、いまやめちゃうと、今までの１時間無駄になっちゃうんだもん。\tそうですねぇ。こまりましたねぇ。\n', 'でしょ。だからセーブできるまでまって。\tでも、わたしはAさんのお世話しなければなりませんしね。Aさんにとって、よくない事は賛成することはできないのですよ。\n', 'そうなんだ。ロボットも、ぼくのお世話も大変なんだねえ。\tそんなこといって。Aさん、あなた辞める気ありますか？\n']
# ['えぇまだいいじゃん。\tいえやり過ぎです。\n', 'ちぇっ。\tちゃんと時間を決めたらどうです？\n', '面倒くさいよ。\tゲームをし過ぎると目も悪くなりますし。\n', '僕のことなんだし関係ないでしょ！\t関係ありますよ！\n', 'えっ。\tもしあなたに何かあったら私は悲しいです。\n']
# ['まだ綺麗な方だからいいよ。\t部屋を綺麗にできない人はモテないよ\n', 'えー、めんどくさいよ。\tじゃあ、いつするの？\n', 'そうだっけ？\t綺麗な部屋は気持ちがいんだよ。\n', 'どう気持ちがいいの？\t気分がスッキリして晴れやかな気持ちになれるんだよ。\n', '最近ついてなくて気分がすぐれないんだよね。\tそんな時こそ掃除するべきだよ。\n']
# ['まだそんなに散らかっていないよ。\t足の踏み場もないくらいだけど。\n', '必要な物が取りやすくていいんだよ。\tどこに何を置いてあるか分からなくなるでしょう。\n', 'もうある程度の場所は覚えたよ。\tこれだけ物が散乱していると掃除機をかけることも出来ないじゃない。\n', 'だから当分の間は必要ないかな。\t衛生上にもよくないよ。\n', 'そんなに影響がでていると思わないけどなぁ。\tさっきから咳をしているけどそれは埃のせいじゃないかな。\n']
# ['あとでね。今忙しいんだ。\tあとであとでって言うばかりでいつも片付けないじゃないか。\n', 'だってめんどくさいんだもん。そんなに部屋を綺麗にしたいならロボットが掃除したらいいじゃないか。\t私が掃除してもAさんのためにならないよ。掃除してあげてもいいけど私がいなくなったあと誰が掃除するの?\n', '…。ロボットはいなくならないでしょ?\tそれはわからないよ。いつ離れ離れになるか…。そのためにわたしが今指導しているのだよ。\n', 'うーん。でも今は漫画を読んでいるから。無理。\tどうしてこれだけ言ってもわかってくれないの！掃除しないのなら全部捨てるよ！\n', 'え、だめだめ。捨てたらだめだよ、大切なものばかりなんだから。\tだったらなおさら自分で片付けなさい！私だって怒るときは怒るんだ！\n']

# %% [markdown]
# # File check of emotions
# * some dialogue have inadequately format (not user-system such as user-system-user-user-user...)

# %%
def check_files(read_file):
    file_dial = open(read_file + '_dial.txt', 'r')
    file_emotion = open(read_file + '_emotion.txt', 'r')
    dials = file_dial.readlines()
    emotions = file_emotion.readlines()
    for i,r in enumerate(emotions):
        if len(r.split('\t'))!=2:
            print(i,r)
            print(dials[i])

# %%
from_dir = "../data/em_dial/splitted"
domain = ["/cleaning","/exercise","/lunch","/sleep","/game","/all"]
last_part = ["/test","/valid","/train"]

for d in domain:
    for l in last_part:        
        print(d,l)
        check_files(from_dir+d+l)
# Out:
# /cleaning /test
# /cleaning /valid
# /cleaning /train
# /exercise /test
# /exercise /valid
# /exercise /train
# /lunch /test
# /lunch /valid
# /lunch /train
# /sleep /test
# /sleep /valid
# /sleep /train
# /game /test
# /game /valid
# /game /train
# /all /test
# /all /valid
# /all /train

# %% [markdown]
# # Add kaomozi in last part of em_dial
# * try to add kaomozi in training to confirm how reflected emoitons

# %%
id2kao = {"0":"","1":"（・_・）","2":"（怒）","3":"（悲）","4":"（喜）","5":"（安心）"}
id2emo = {"0":"NONE","1":"neutral","2":"anger","3":"sad","4":"happy","5":"contentment"}

# %%
def print_num_emotion(count):
    for i in range(6):
        print("   {} : {}".format(id2emo[str(i)],count[str(i)]))

def add_kaomozi(from_file, out_file):
    file1_dial = open(from_file + '_dial.txt', 'r')
    file2_dial = open(out_file + '_dial.txt', 'w')
    file1_emotion = open(from_file + '_emotion.txt', 'r')
    file2_emotion = open(out_file + '_emotion.txt', 'w')
    
    dials = file1_dial.readlines()
    emotions = file1_emotion.readlines()
    
    for i,r in enumerate(emotions):
        if len(r.split('\t'))!=2:
            print(i,r)
            raise ValueError
    robo_emotions = [emotion.split('\t')[1].strip() for emotion in emotions]
    print_num_emotion(Counter(robo_emotions))
    
    out_dials = []
    [out_dials.append(uttr.strip('\n')+id2kao[emotion]+'\n') for (uttr, emotion) in zip(dials, robo_emotions)]
    file2_dial.writelines(out_dials)
    file2_emotion.writelines(emotions)

# %%
from_dir = "../data/em_dial/splitted"
out_kao_dir = "../data/em_dial/splitted/kao"
domain = ["/cleaning","/exercise","/lunch","/sleep","/game","/all"]
last_part = ["/test","/valid","/train"]

for d in domain:
    if not os.path.exists(out_kao_dir+d):
        os.makedirs(out_kao_dir+d)
    print("\ndomain : ", d)
    for l in last_part:
        print("input file : ", from_dir+d+l)          
        print("output file : ", out_kao_dir+d+l)   
        add_kaomozi(from_dir+d+l, out_kao_dir+d+l)
# Out:
# domain :  /cleaning
# input file :  ../data/em_dial/splitted/cleaning/test
# output file :  ../data/em_dial/splitted/kao/cleaning/test
#    NONE : 37
#    neutral : 25
#    anger : 75
#    sad : 46
#    happy : 18
#    contentment : 4
# input file :  ../data/em_dial/splitted/cleaning/valid
# output file :  ../data/em_dial/splitted/kao/cleaning/valid
#    NONE : 29
#    neutral : 31
#    anger : 48
#    sad : 67
#    happy : 27
#    contentment : 1
# input file :  ../data/em_dial/splitted/cleaning/train
# output file :  ../data/em_dial/splitted/kao/cleaning/train
#    NONE : 265
#    neutral : 318
#    anger : 412
#    sad : 462
#    happy : 199
#    contentment : 28
#
# domain :  /exercise
# input file :  ../data/em_dial/splitted/exercise/test
# output file :  ../data/em_dial/splitted/kao/exercise/test
#    NONE : 22
#    neutral : 63
#    anger : 37
#    sad : 43
#    happy : 29
#    contentment : 5
# input file :  ../data/em_dial/splitted/exercise/valid
# output file :  ../data/em_dial/splitted/kao/exercise/valid
#    NONE : 22
#    neutral : 90
#    anger : 28
#    sad : 37
#    happy : 36
#    contentment : 9
# input file :  ../data/em_dial/splitted/exercise/train
# output file :  ../data/em_dial/splitted/kao/exercise/train
#    NONE : 197
#    neutral : 498
#    anger : 259
#    sad : 312
#    happy : 291
#    contentment : 41
#
# domain :  /lunch
# input file :  ../data/em_dial/splitted/lunch/test
# output file :  ../data/em_dial/splitted/kao/lunch/test
#    NONE : 25
#    neutral : 68
#    anger : 44
#    sad : 47
#    happy : 15
#    contentment : 8
# input file :  ../data/em_dial/splitted/lunch/valid
# output file :  ../data/em_dial/splitted/kao/lunch/valid
#    NONE : 24
#    neutral : 54
#    anger : 29
#    sad : 63
#    happy : 20
#    contentment : 9
# input file :  ../data/em_dial/splitted/lunch/train
# output file :  ../data/em_dial/splitted/kao/lunch/train
#    NONE : 217
#    neutral : 435
#    anger : 337
#    sad : 381
#    happy : 159
#    contentment : 50
#
# domain :  /sleep
# input file :  ../data/em_dial/splitted/sleep/test
# output file :  ../data/em_dial/splitted/kao/sleep/test
#    NONE : 20
#    neutral : 60
#    anger : 38
#    sad : 51
#    happy : 16
#    contentment : 5
# input file :  ../data/em_dial/splitted/sleep/valid
# output file :  ../data/em_dial/splitted/kao/sleep/valid
#    NONE : 14
#    neutral : 72
#    anger : 45
#    sad : 43
#    happy : 14
#    contentment : 13
# input file :  ../data/em_dial/splitted/sleep/train
# output file :  ../data/em_dial/splitted/kao/sleep/train
#    NONE : 172
#    neutral : 512
#    anger : 392
#    sad : 294
#    happy : 131
#    contentment : 89
#
# domain :  /game
# input file :  ../data/em_dial/splitted/game/test
# output file :  ../data/em_dial/splitted/kao/game/test
#    NONE : 18
#    neutral : 49
#    anger : 48
#    sad : 49
#    happy : 13
#    contentment : 7
# input file :  ../data/em_dial/splitted/game/valid
# output file :  ../data/em_dial/splitted/kao/game/valid
#    NONE : 14
#    neutral : 65
#    anger : 42
#    sad : 54
#    happy : 14
#    contentment : 3
# input file :  ../data/em_dial/splitted/game/train
# output file :  ../data/em_dial/splitted/kao/game/train
#    NONE : 202
#    neutral : 402
#    anger : 496
#    sad : 325
#    happy : 116
#    contentment : 36
#
# domain :  /all
# input file :  ../data/em_dial/splitted/all/test
# output file :  ../data/em_dial/splitted/kao/all/test
#    NONE : 95
#    neutral : 226
#    anger : 158
#    sad : 180
#    happy : 71
#    contentment : 28
# input file :  ../data/em_dial/splitted/all/valid
# output file :  ../data/em_dial/splitted/kao/all/valid
#    NONE : 125
#    neutral : 263
#    anger : 216
#    sad : 238
#    happy : 114
#    contentment : 35
# input file :  ../data/em_dial/splitted/all/train
# output file :  ../data/em_dial/splitted/kao/all/train
#    NONE : 1034
#    neutral : 2213
#    anger : 1906
#    sad : 1787
#    happy : 895
#    contentment : 239

# %% [markdown]
# * add including kaomozi vocab in twitter_dial_txt and em_dial_txt ・・・ data/train_kao/spvocab.model

# %%
def concat_dials(from_file1, from_file2, out_file):
    file1_dial = open(from_file1, 'r')
    file2_dial = open(from_file2, 'r')
    file3_dial = open(out_file, 'w')
    dials1 = file1_dial.readlines()
    print("length of from_file1 : ", len(dials1))
    dials2 = file2_dial.readlines()
    print("length of from_file2 : ", len(dials2))
    both = dials1 + dials2
    print("length of output_file : ", len(both))
    
    file3_dial.writelines(both)

# %%
em_kao_file = "../data/em_dial/splitted/kao/over_sample/all/train_dial.txt"
twitter_file = "../data/twitter_dial/splitted/train_dial.txt"
out_vocab_file = "../data/em_dial/vocab/tw_emkao/tw_emkao_train.txt"
concat_dials(em_kao_file, twitter_file, out_vocab_file)
# Out:
# length of from_file1 :  13278
# length of from_file2 :  2813875
# length of output_file :  2827153

# %% [markdown]
# * Build vocablary command
# ```
# python ../preprocess_em/build_spvocab.py \
#     --input ../data/em_dial/vocab/tw_emkao/tw_emkao_train.txt \
#     --model ../data/em_dial/vocab/tw_emkao/spvocab \
#     --size 32000 \
#     --coverage 0.9995
# ```

# %% [markdown]
# * Confirm if building vocab success

# %%
conf_vocab_model = "../data/em_dial/vocab/tw_emkao/spvocab.model"

import sentencepiece as spm
sp = spm.SentencePieceProcessor()
sp.Load(conf_vocab_model)
for kao in id2kao.values():
    encoded = sp.EncodeAsIds(kao)
    print("encoded {} : {}".format(kao,encoded))
    decoded = sp.DecodeIds(encoded)
    print("decoded {} : {}".format(kao,decoded))
# Out:
# encoded （・_・） : [4, 1989, 1793, 259]
# decoded （・_・） : (・_・)
# encoded （悲） : [4, 1989, 1675, 259]
# decoded （悲） : (悲)
# encoded （喜） : [4, 1989, 7772, 259]
# decoded （喜） : (喜)
# encoded  : []
# decoded  :
# encoded （安心） : [4, 1989, 816, 259]
# decoded （安心） : (安心)
# encoded （怒） : [4, 1989, 1093, 259]
# decoded （怒） : (怒)

# %%
print(sp.EncodeAsIds("悲"))
print(sp.DecodeIds([4]))
# Out:
# [4, 1675]

# %% [markdown]
# # Over sampling
# * Because em_dial have unvalunced number of emotion labels, we should over sampling

# %%
def over_sampling(from_file, out_file):
    file1_dial = open(from_file + '_dial.txt', 'r')
    file2_dial = open(out_file + '_dial.txt', 'w')
    file1_emotion = open(from_file + '_emotion.txt', 'r')
    file2_emotion = open(out_file + '_emotion.txt', 'w')  
    dials = file1_dial.readlines()
    emotions = file1_emotion.readlines()
    robo_emotions = [emotion.split('\t')[1].strip() for emotion in emotions]
    count_emo = Counter(robo_emotions)
    # freq_emo is number of most frequency emotions
    freq_emo = count_emo.most_common()[0][1]
    print("Count emotions : ", count_emo)
    times = [int(freq_emo/count_emo[str(i)]) for i in range(6)]
    print("times : ", times)
    plas = [freq_emo - times[i]*count_emo[str(i)] for i in range(6)]
    print("plas : ", plas)
    out_dials = []
    out_emotions = []
    
    for i, (uttr, emotion) in enumerate(zip(dials, robo_emotions)):
        emotion = int(emotion)
        if plas[emotion] != 0:
            (out_dials.append(uttr), out_emotions.append(emotions[i]))
            plas[emotion] = plas[emotion]-1
        for j in range(times[emotion]):
            (out_dials.append(uttr), out_emotions.append(emotions[i]))            
    file2_dial.writelines(out_dials)
    file2_emotion.writelines(out_emotions)

# %%
from_dir = "../data/em_dial/splitted"
out_over_dir = "../data/em_dial/splitted/over_sample"
domain = ["/cleaning","/exercise","/lunch","/sleep","/game","/all"]
last_part = ["/test","/valid","/train"]

for d in domain:
    if not os.path.exists(out_over_dir+d):
        os.makedirs(out_over_dir+d)
    for l in last_part:
        print("output file : ", out_over_dir+d+l)
        over_sampling(from_dir+d+l, out_over_dir+d+l)
# Out:
# output file :  ../data/em_dial/splitted/over_sample/cleaning/test
# Count emotions :  Counter({'2': 75, '3': 46, '0': 37, '1': 25, '4': 18, '5': 4})
# times :  [2, 3, 1, 1, 4, 18]
# plas :  [1, 0, 0, 29, 3, 3]
# output file :  ../data/em_dial/splitted/over_sample/cleaning/valid
# Count emotions :  Counter({'3': 67, '2': 48, '1': 31, '0': 29, '4': 27, '5': 1})
# times :  [2, 2, 1, 1, 2, 67]
# plas :  [9, 5, 19, 0, 13, 0]
# output file :  ../data/em_dial/splitted/over_sample/cleaning/train
# Count emotions :  Counter({'3': 462, '2': 412, '1': 318, '0': 265, '4': 199, '5': 28})
# times :  [1, 1, 1, 1, 2, 16]
# plas :  [197, 144, 50, 0, 64, 14]
# output file :  ../data/em_dial/splitted/over_sample/exercise/test
# Count emotions :  Counter({'1': 63, '3': 43, '2': 37, '4': 29, '0': 22, '5': 5})
# times :  [2, 1, 1, 1, 2, 12]
# plas :  [19, 0, 26, 20, 5, 3]
# output file :  ../data/em_dial/splitted/over_sample/exercise/valid
# Count emotions :  Counter({'1': 90, '3': 37, '4': 36, '2': 28, '0': 22, '5': 9})
# times :  [4, 1, 3, 2, 2, 10]
# plas :  [2, 0, 6, 16, 18, 0]
# output file :  ../data/em_dial/splitted/over_sample/exercise/train
# Count emotions :  Counter({'1': 498, '3': 312, '4': 291, '2': 259, '0': 197, '5': 41})
# times :  [2, 1, 1, 1, 1, 12]
# plas :  [104, 0, 239, 186, 207, 6]
# output file :  ../data/em_dial/splitted/over_sample/lunch/test
# Count emotions :  Counter({'1': 68, '3': 47, '2': 44, '0': 25, '4': 15, '5': 8})
# times :  [2, 1, 1, 1, 4, 8]
# plas :  [18, 0, 24, 21, 8, 4]
# output file :  ../data/em_dial/splitted/over_sample/lunch/valid
# Count emotions :  Counter({'3': 63, '1': 54, '2': 29, '0': 24, '4': 20, '5': 9})
# times :  [2, 1, 2, 1, 3, 7]
# plas :  [15, 9, 5, 0, 3, 0]
# output file :  ../data/em_dial/splitted/over_sample/lunch/train
# Count emotions :  Counter({'1': 435, '3': 381, '2': 337, '0': 217, '4': 159, '5': 50})
# times :  [2, 1, 1, 1, 2, 8]
# plas :  [1, 0, 98, 54, 117, 35]
# output file :  ../data/em_dial/splitted/over_sample/sleep/test
# Count emotions :  Counter({'1': 60, '3': 51, '2': 38, '0': 20, '4': 16, '5': 5})
# times :  [3, 1, 1, 1, 3, 12]
# plas :  [0, 0, 22, 9, 12, 0]
# output file :  ../data/em_dial/splitted/over_sample/sleep/valid
# Count emotions :  Counter({'1': 72, '2': 45, '3': 43, '4': 14, '0': 14, '5': 13})
# times :  [5, 1, 1, 1, 5, 5]
# plas :  [2, 0, 27, 29, 2, 7]
# output file :  ../data/em_dial/splitted/over_sample/sleep/train
# Count emotions :  Counter({'1': 512, '2': 392, '3': 294, '0': 172, '4': 131, '5': 89})
# times :  [2, 1, 1, 1, 3, 5]
# plas :  [168, 0, 120, 218, 119, 67]
# output file :  ../data/em_dial/splitted/over_sample/game/test
# Count emotions :  Counter({'3': 49, '1': 49, '2': 48, '0': 18, '4': 13, '5': 7})
# times :  [2, 1, 1, 1, 3, 7]
# plas :  [13, 0, 1, 0, 10, 0]
# output file :  ../data/em_dial/splitted/over_sample/game/valid
# Count emotions :  Counter({'1': 65, '3': 54, '2': 42, '4': 14, '0': 14, '5': 3})
# times :  [4, 1, 1, 1, 4, 21]
# plas :  [9, 0, 23, 11, 9, 2]
# output file :  ../data/em_dial/splitted/over_sample/game/train
# Count emotions :  Counter({'2': 496, '1': 402, '3': 325, '0': 202, '4': 116, '5': 36})
# times :  [2, 1, 1, 1, 4, 13]
# plas :  [92, 94, 0, 171, 32, 28]
# output file :  ../data/em_dial/splitted/over_sample/all/test
# Count emotions :  Counter({'1': 226, '3': 180, '2': 158, '0': 95, '4': 71, '5': 28})
# times :  [2, 1, 1, 1, 3, 8]
# plas :  [36, 0, 68, 46, 13, 2]
# output file :  ../data/em_dial/splitted/over_sample/all/valid
# Count emotions :  Counter({'1': 263, '3': 238, '2': 216, '0': 125, '4': 114, '5': 35})
# times :  [2, 1, 1, 1, 2, 7]
# plas :  [13, 0, 47, 25, 35, 18]
# output file :  ../data/em_dial/splitted/over_sample/all/train
# Count emotions :  Counter({'1': 2213, '2': 1906, '3': 1787, '0': 1034, '4': 895, '5': 239})
# times :  [2, 1, 1, 1, 2, 9]
# plas :  [145, 0, 307, 426, 423, 62]

# %% [markdown]
# # Make file of over sampling and  kaomozi

# %%
from_dir = "../data/em_dial/splitted/over_sample"
out_over_kao_dir = "../data/em_dial/splitted/kao/over_sample"
domain = ["/cleaning","/exercise","/lunch","/sleep","/game","/all"]
last_part = ["/test","/valid","/train"]

for d in domain:
    if not os.path.exists(out_over_kao_dir+d):
        os.makedirs(out_over_kao_dir+d)
    for l in last_part:
        print("output file : ", out_over_kao_dir+d+l)   
        add_kaomozi(from_dir+d+l, out_over_kao_dir+d+l)
# Out:
# output file :  ../data/em_dial/splitted/kao/over_sample/cleaning/test
#    NONE : 75
#    neutral : 75
#    anger : 75
#    sad : 75
#    happy : 75
#    contentment : 75
# output file :  ../data/em_dial/splitted/kao/over_sample/cleaning/valid
#    NONE : 67
#    neutral : 67
#    anger : 67
#    sad : 67
#    happy : 67
#    contentment : 67
# output file :  ../data/em_dial/splitted/kao/over_sample/cleaning/train
#    NONE : 462
#    neutral : 462
#    anger : 462
#    sad : 462
#    happy : 462
#    contentment : 462
# output file :  ../data/em_dial/splitted/kao/over_sample/exercise/test
#    NONE : 63
#    neutral : 63
#    anger : 63
#    sad : 63
#    happy : 63
#    contentment : 63
# output file :  ../data/em_dial/splitted/kao/over_sample/exercise/valid
#    NONE : 90
#    neutral : 90
#    anger : 90
#    sad : 90
#    happy : 90
#    contentment : 90
# output file :  ../data/em_dial/splitted/kao/over_sample/exercise/train
#    NONE : 498
#    neutral : 498
#    anger : 498
#    sad : 498
#    happy : 498
#    contentment : 498
# output file :  ../data/em_dial/splitted/kao/over_sample/lunch/test
#    NONE : 68
#    neutral : 68
#    anger : 68
#    sad : 68
#    happy : 68
#    contentment : 68
# output file :  ../data/em_dial/splitted/kao/over_sample/lunch/valid
#    NONE : 63
#    neutral : 63
#    anger : 63
#    sad : 63
#    happy : 63
#    contentment : 63
# output file :  ../data/em_dial/splitted/kao/over_sample/lunch/train
#    NONE : 435
#    neutral : 435
#    anger : 435
#    sad : 435
#    happy : 435
#    contentment : 435
# output file :  ../data/em_dial/splitted/kao/over_sample/sleep/test
#    NONE : 60
#    neutral : 60
#    anger : 60
#    sad : 60
#    happy : 60
#    contentment : 60
# output file :  ../data/em_dial/splitted/kao/over_sample/sleep/valid
#    NONE : 72
#    neutral : 72
#    anger : 72
#    sad : 72
#    happy : 72
#    contentment : 72
# output file :  ../data/em_dial/splitted/kao/over_sample/sleep/train
#    NONE : 512
#    neutral : 512
#    anger : 512
#    sad : 512
#    happy : 512
#    contentment : 512
# output file :  ../data/em_dial/splitted/kao/over_sample/game/test
#    NONE : 49
#    neutral : 49
#    anger : 49
#    sad : 49
#    happy : 49
#    contentment : 49
# output file :  ../data/em_dial/splitted/kao/over_sample/game/valid
#    NONE : 65
#    neutral : 65
#    anger : 65
#    sad : 65
#    happy : 65
#    contentment : 65
# output file :  ../data/em_dial/splitted/kao/over_sample/game/train
#    NONE : 496
#    neutral : 496
#    anger : 496
#    sad : 496
#    happy : 496
#    contentment : 496
# output file :  ../data/em_dial/splitted/kao/over_sample/all/test
#    NONE : 226
#    neutral : 226
#    anger : 226
#    sad : 226
#    happy : 226
#    contentment : 226
# output file :  ../data/em_dial/splitted/kao/over_sample/all/valid
#    NONE : 263
#    neutral : 263
#    anger : 263
#    sad : 263
#    happy : 263
#    contentment : 263
# output file :  ../data/em_dial/splitted/kao/over_sample/all/train
#    NONE : 2213
#    neutral : 2213
#    anger : 2213
#    sad : 2213
#    happy : 2213
#    contentment : 2213
